# %%
class Filme:

    def __init__(self, nome, ano, duracao):
        self.__nome = nome.title()
        self.ano = ano
        self.duracao = duracao
        self.__like = 0

    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()

class Serie:
    
    def __init__(self, nome, ano, temporadas):
        self.__nome = nome.title()
        self.ano = ano
        self.temporadas = temporadas
        self.__like = 0

    def dar_likes(self):
        self.__like += 1

    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()




vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)

vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()

print(f"Nome: {vingadores.nome} - Ano: {vingadores.ano} - Duração: {vingadores.duracao} - Likes: {vingadores.like}")
print(f"Nome: {atlanta.nome} - Ano: {atlanta.ano} - Temporada: {atlanta.temporadas} - Likes: {atlanta.like}")

# %% [markdown]
# ##### - Herança

# %% [markdown]
# Da maneira que o código está ele tem muita repetição. Isso não é bom e para resolvermos esse problema usaremos o conceito de herança!

# %%
class Programa:                                     # Essa é a nossa superclasse
       
    def __init__(self, nome, ano):
        self.__nome = nome.title()
        self.ano = ano
        self.__like = 0


    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()


class Filme (Programa):                             # Classe filha.

    def __init__(self, nome, ano, duracao):
        super().__init__(nome, ano)                 # aqui ele "chama" o "__init__" da classe mãe.
        self.duracao = duracao


class Serie (Programa):                             # Classe filha.
    
    def __init__(self, nome, ano, temporadas):
        super().__init__(nome, ano)
        self.temporadas = temporadas





vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)

vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()

print(f"Nome: {vingadores.nome} - Ano: {vingadores.ano} - Duração: {vingadores.duracao} - Likes: {vingadores.like}")
print(f"Nome: {atlanta.nome} - Ano: {atlanta.ano} - Temporada: {atlanta.temporadas} - Likes: {atlanta.like}")

# %% [markdown]
# como podemos ver Todo o código que estava duplicado nas classes foi passado para a classe mãe.

# %% [markdown]
# ##### - Polimorfismo!

# %% [markdown]
# Usaremos o Polimorfismo para substituir esses printes que temos ao final do código. Primeiramene faremos a criação da play_list.

# %%
class Programa:                                     
    
    def __init__(self, nome, ano):
        self.__nome = nome.title()
        self.ano = ano
        self.__like = 0


    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()


class Filme (Programa):                             

    def __init__(self, nome, ano, duracao):
        super().__init__(nome, ano)                 
        self.duracao = duracao


class Serie (Programa):                             
    
    def __init__(self, nome, ano, temporadas):
        super().__init__(nome, ano)
        self.temporadas = temporadas



play_list = []

vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)

play_list.append(vingadores)
play_list.append(atlanta)


vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()

print(f"Nome: {vingadores.nome} - Ano: {vingadores.ano} - Duração: {vingadores.duracao} min - Likes: {vingadores.like}")
print(f"Nome: {atlanta.nome} - Ano: {atlanta.ano} - Temporada(s): {atlanta.temporadas} - Likes: {atlanta.like}")

# %% [markdown]
# - Depois de criada a play_list usaremos a estrutura do "for ... in" para substituir os prints que estão ao final da célula anterior.

# %%
class Programa:                                     
    
    def __init__(self, nome, ano):
        self.__nome = nome.title()
        self.ano = ano
        self.__like = 0


    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()


class Filme (Programa):                             

    def __init__(self, nome, ano, duracao):
        super().__init__(nome, ano)                 
        self.duracao = duracao


class Serie (Programa):                             
    
    def __init__(self, nome, ano, temporadas):
        super().__init__(nome, ano)
        self.temporadas = temporadas



play_list = []

vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)

play_list.append(vingadores)
play_list.append(atlanta)


vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()


for programa in play_list:
    if hasattr (programa, 'duracao'):
        print(f"Nome: {programa.nome} - Ano: {programa.ano} - Duração: {programa.duracao} min - Likes: {programa.like}")
    else:
        print(f"Nome: {atlanta.nome} - Ano: {atlanta.ano} - Temporada(s): {atlanta.temporadas} - Likes: {atlanta.like}")

# %% [markdown]
# Agora usaremos o polimorfismo para trocar esse 'for' por outra 'coisa'. Criaremos um atributo chamado imprime para cada classe!

# %%
class Programa:                                     
    
    def __init__(self, nome, ano):
        self.__nome = nome.title()
        self.ano = ano
        self.__like = 0


    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()

    def imprime(self):
        print(f"Nome: {self.nome} - Ano: {self.ano} - Likes: {self.like}")


class Filme (Programa):                            

    def __init__(self, nome, ano, duracao):
        super().__init__(nome, ano)                 
        self.duracao = duracao
    
    def imprime(self):
        print(f"Nome: {self.nome} - Ano: {self.ano} - Duração: {self.duracao} min - Likes: {self.like}")


class Serie (Programa):                             
    
    def __init__(self, nome, ano, temporadas):
        super().__init__(nome, ano)
        self.temporadas = temporadas

    def imprime(self):
        print(f"Nome: {self.nome} - Ano: {self.ano} - Temporada(s): {self.temporadas} - Likes: {self.like}")

play_list = []

vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)

play_list.append(vingadores)
play_list.append(atlanta)


vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()


for programa in play_list:
    programa.imprime()
# Out:
# Nome: Vinadores - Guerra Infinira - Ano: 2018 - Duração: 160 min - Likes: 3
# Nome: Atlanta - Ano: 2018 - Temporada(s): 2 - Likes: 2

# %% [markdown]
# Agora queremos representar cada uma das classes de forma textual, para isso usaremos o método "__str__" (no caso usaremos esse método no lugar da função imprime em cada uma das
# classes.)

# %%
class Programa:                                     
    
    def __init__(self, nome, ano):
        self.__nome = nome.title()
        self.ano = ano
        self.__like = 0


    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()

    def __str__(self):                                                              #representação textual da classe!
        return f"Nome: {self.nome} - Ano: {self.ano} - Likes: {self.like}"


class Filme (Programa):                             

    def __init__(self, nome, ano, duracao):
        super().__init__(nome, ano)                 
        self.duracao = duracao
    
    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Duração: {self.duracao} min - Likes: {self.like}"


class Serie (Programa):                             
    
    def __init__(self, nome, ano, temporadas):
        super().__init__(nome, ano)
        self.temporadas = temporadas

    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Temporada(s): {self.temporadas} - Likes: {self.like}"

play_list = []

vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)

play_list.append(vingadores)
play_list.append(atlanta)


vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()


for programa in play_list:
    print(programa)
# Out:
# Nome: Vinadores - Guerra Infinira - Ano: 2018 - Duração: 160 min - Likes: 3
# Nome: Atlanta - Ano: 2018 - Temporada(s): 2 - Likes: 2

# %% [markdown]
# - Vamos criar uma classe "Playlist", com atributos: nomes e programas. E que tenha um método que nos devolva o tamanho da playlist.
# - Após isso precisaremos mudar novamente a estrutura do nosso for ao final do código.

# %%
class Programa:                                     
    
    def __init__(self, nome, ano):
        self.__nome = nome.title()
        self.ano = ano
        self.__like = 0


    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()

    def __str__(self):                                                              
        return f"Nome: {self.nome} - Ano: {self.ano} - Likes: {self.like}"


class Filme (Programa):                             

    def __init__(self, nome, ano, duracao):
        super().__init__(nome, ano)                 
        self.duracao = duracao
    
    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Duração: {self.duracao} min - Likes: {self.like}"


class Serie (Programa):                             
    
    def __init__(self, nome, ano, temporadas):
        super().__init__(nome, ano)
        self.temporadas = temporadas

    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Temporada(s): {self.temporadas} - Likes: {self.like}"

class Playlist:

    def __init__(self, nome, programas):
        self.nome = nome
        self.programas = programas

    def tamanho (self):
        return len(self.programas)
    


vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)
tmep = Filme('Todo mundo em pânico', 1999, 100)
demolidor = Serie ('Demolidor', 2016, 2)

filmes_e_series = [vingadores, atlanta, demolidor, tmep]

play_list_fim_de_semana = Playlist('Fim de semana', filmes_e_series)

vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()

demolidor.dar_likes()
demolidor.dar_likes()
demolidor.dar_likes()

tmep.dar_likes()



for programa in play_list_fim_de_semana.programas:
    print(programa)
# Out:
# Nome: Vinadores - Guerra Infinira - Ano: 2018 - Duração: 160 min - Likes: 3
# Nome: Atlanta - Ano: 2018 - Temporada(s): 2 - Likes: 2
# Nome: Demolidor - Ano: 2016 - Temporada(s): 2 - Likes: 3
# Nome: Todo Mundo Em Pânico - Ano: 1999 - Duração: 100 min - Likes: 1

# %% [markdown]
# - Agora nos gostariamos de usar o for percorrendo a **"play_list_fim_de_semana"** e não **"play_list_fim_de_semana.programas"**. Como faremos isso?
#
# - Faremos  a calsse "Playlist" herdar da list.

# %%
class Programa:                                     
    def __init__(self, nome, ano):
        self.__nome = nome.title()
        self.ano = ano
        self.__like = 0


    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()

    def __str__(self):                                                              
        return f"Nome: {self.nome} - Ano: {self.ano} - Likes: {self.like}"


class Filme (Programa):                             

    def __init__(self, nome, ano, duracao):
        super().__init__(nome, ano)                
        self.duracao = duracao
    
    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Duração: {self.duracao} min - Likes: {self.like}"


class Serie (Programa):                            
    
    def __init__(self, nome, ano, temporadas):
        super().__init__(nome, ano)
        self.temporadas = temporadas

    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Temporada(s): {self.temporadas} - Likes: {self.like}"


class Playlist(list):

    def __init__(self, nome, programas):
        self.nome = nome
        super().__init__(programas)

    # retirei isso porque herdando as propriedades de list posso usar a função len
    # def tamanho (self):
    #     return len(self.programas)
     


vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)
tmep = Filme('Todo mundo em pânico', 1999, 100)
demolidor = Serie ('Demolidor', 2016, 2)

filmes_e_series = [vingadores, atlanta, demolidor, tmep]

play_list_fim_de_semana = Playlist('Fim de semana', filmes_e_series)

vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()

demolidor.dar_likes()
demolidor.dar_likes()
demolidor.dar_likes()

tmep.dar_likes()

print(f"O tamanho da sua playlist é: {len(play_list_fim_de_semana)}")
print("\n")

for programa in play_list_fim_de_semana:
    print(programa)
# Out:
# O tamanho da sua playlist é: 4
#
#
# Nome: Vinadores - Guerra Infinira - Ano: 2018 - Duração: 160 min - Likes: 3
# Nome: Atlanta - Ano: 2018 - Temporada(s): 2 - Likes: 2
# Nome: Demolidor - Ano: 2016 - Temporada(s): 2 - Likes: 3
# Nome: Todo Mundo Em Pânico - Ano: 1999 - Duração: 100 min - Likes: 1

# %% [markdown]
# Vimos que herdar da lista não é uma idéia tão boa. Então vamos aprender como usar o '__ getitem __' (Python Data Model).

# %%
class Programa:                                    
    
    def __init__(self, nome, ano):
        self.__nome = nome.title()
        self.ano = ano
        self.__like = 0


    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()

    def __str__(self):                                                              
        return f"Nome: {self.nome} - Ano: {self.ano} - Likes: {self.like}"


class Filme (Programa):                             

    def __init__(self, nome, ano, duracao):
        super().__init__(nome, ano)                 
        self.duracao = duracao
    
    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Duração: {self.duracao} min - Likes: {self.like}"


class Serie (Programa):                             
    
    def __init__(self, nome, ano, temporadas):
        super().__init__(nome, ano)
        self.temporadas = temporadas

    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Temporada(s): {self.temporadas} - Likes: {self.like}"


class Playlist:

    def __init__(self, nome, programas):
        self.nome = nome
        self.programas = programas

    def __getitem__(self, item):                    # indica que nessa classe temos um atributo (programas) que se comporta como um iterável.
        return self.programas[item]

    @property
    def lista_de_programas(self):
        return self.programas
    
    @property
    def tamanho (self):
        return len(self.programas)


vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)
tmep = Filme('Todo mundo em pânico', 1999, 100)
demolidor = Serie ('Demolidor', 2016, 2)

filmes_e_series = [vingadores, atlanta, demolidor, tmep]

play_list_fim_de_semana = Playlist('Fim de semana', filmes_e_series)

vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()

demolidor.dar_likes()
demolidor.dar_likes()
demolidor.dar_likes()

tmep.dar_likes()

print(f"O tamanho da sua playlist é: {play_list_fim_de_semana.tamanho}")
print("\n")

for programa in play_list_fim_de_semana:
    print(programa)
# Out:
# O tamanho da sua playlist é: 4
#
#
# Nome: Vinadores - Guerra Infinira - Ano: 2018 - Duração: 160 min - Likes: 3
# Nome: Atlanta - Ano: 2018 - Temporada(s): 2 - Likes: 2
# Nome: Demolidor - Ano: 2016 - Temporada(s): 2 - Likes: 3
# Nome: Todo Mundo Em Pânico - Ano: 1999 - Duração: 100 min - Likes: 1

# %% [markdown]
# Aprendendo sobre outro "método mágico" com len

# %%
class Programa:                                    
    
    def __init__(self, nome, ano):
        self.__nome = nome.title()
        self.ano = ano
        self.__like = 0


    def dar_likes(self):
        self.__like += 1
    
    @property
    def nome (self):
        return self.__nome
    
    @property
    def like (self):
        return self.__like
    
    @nome.setter
    def nome(self, novo_nome):
        self.__nome = novo_nome.title()

    def __str__(self):                                                              
        return f"Nome: {self.nome} - Ano: {self.ano} - Likes: {self.like}"


class Filme (Programa):                             

    def __init__(self, nome, ano, duracao):
        super().__init__(nome, ano)                 
        self.duracao = duracao
    
    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Duração: {self.duracao} min - Likes: {self.like}"


class Serie (Programa):                             
    
    def __init__(self, nome, ano, temporadas):
        super().__init__(nome, ano)
        self.temporadas = temporadas

    def __str__(self):
        return f"Nome: {self.nome} - Ano: {self.ano} - Temporada(s): {self.temporadas} - Likes: {self.like}"


class Playlist:

    def __init__(self, nome, programas):
        self.nome = nome
        self.programas = programas

    def __getitem__(self, item):                    # indica que nessa classe temos um atributo (programas) que se comporta como um iterável.
        return self.programas[item]

    def __len__ (self):
        return len(self.programas)
    
    @property
    def lista_de_programas(self):
        return self.programas
    



vingadores = Filme('Vinadores - guerra infinira', 2018, 160)
atlanta = Serie('atlanta', 2018, 2)
tmep = Filme('Todo mundo em pânico', 1999, 100)
demolidor = Serie ('Demolidor', 2016, 2)

filmes_e_series = [vingadores, atlanta, demolidor, tmep]

play_list_fim_de_semana = Playlist('Fim de semana', filmes_e_series)

vingadores.dar_likes()
vingadores.dar_likes()
vingadores.dar_likes()

atlanta.dar_likes()
atlanta.dar_likes()

demolidor.dar_likes()
demolidor.dar_likes()
demolidor.dar_likes()

tmep.dar_likes()

print(f"O tamanho da sua playlist é: {len(play_list_fim_de_semana)}")
print("\n")

for programa in play_list_fim_de_semana:
    print(programa)
# Out:
# O tamanho da sua playlist é: 4
#
#
# Nome: Vinadores - Guerra Infinira - Ano: 2018 - Duração: 160 min - Likes: 3
# Nome: Atlanta - Ano: 2018 - Temporada(s): 2 - Likes: 2
# Nome: Demolidor - Ano: 2016 - Temporada(s): 2 - Likes: 3
# Nome: Todo Mundo Em Pânico - Ano: 1999 - Duração: 100 min - Likes: 1

# %% [markdown]
# Como garantir que uma subclasse seja "obrigada" a implementar determinado método??
#
# Para isso fazer usar os abstract base classes/abstract methods ('@abstractmethod')

# %%
from abc import ABC # abstract base classes (ABC)
